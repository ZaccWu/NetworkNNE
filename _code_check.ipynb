# %%
import numpy as np
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from Positive_transform import Positive_transform
from sklearn.preprocessing import StandardScaler
from normalRegressionLayer import NormalRegressionLayer
import pickle
from Test_error_summary import Test_error_summary
import sys
import argparse
import shap
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
def getTrainArgs():
    parser = argparse.ArgumentParser('nneTrain')
    # neural network algorithm/training settings
    parser.add_argument('--num_nodes', type=int, help='layer width', default=128)   # 128
    parser.add_argument('--batch_size', type=int, help='training sample batch', default=32)    # 256
    parser.add_argument('--max_epochs', type=int, help='training epoches', default=100)         # 100
    parser.add_argument('--initial_lr', type=int, help='initial learning rate', default=0.01)   # 0.01

    # display settings
    parser.add_argument('--enable_shapley', type=bool, help='shapley value analysis', default=True)
    parser.add_argument('--disp_test_summary', type=bool, help='display test summary', default=True)
    parser.add_argument('--display_fig', type=bool, help='display figure', default=True) # True
    parser.add_argument('--disp_iter', type=bool, help='display iteration', default=True)
    parser.add_argument('--learn_standard_error', type=bool, help='learn standard error', default=False)

    try:
        args = parser.parse_args([])  # Pass empty list to ignore kernel args
        return args
    except:
        parser.print_help()
        sys.exit(0)
    

def set_train_seed(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)

class NeuralNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()

        self.model = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ELU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ELU(),
            nn.Linear(hidden_dim, output_dim),
        )

    def forward(self, x):
        return self.model(x)

def forward_loss(Y, T): # y_pred, y_true
    #print(Y.shape)
    #print(T.shape)
    k = Y.shape[1] // 2
    n = Y.shape[0]
    U = Y[:, :k]
    S = torch.tensor(Positive_transform(Y[:, k:2*k].detach().numpy()))
    S = S+1e-8
    X = T[:, :k]
    squared_err = 2 * torch.log(S) + ((U - X) / S) ** 2
    # sum all elements, then divide by n
    loss = squared_err.sum() / n
    return loss

# %%
args = getTrainArgs()
with open('results/results-20260409//training_set_gen_p2.pkl', 'rb') as f:
#with open('training_set_gen.pkl', 'rb') as f:  # data from "set_up.py"
    data = pickle.load(f)
set_train_seed(101)

# %%
input_train, label_train = data['input_train'], data['label_train']
input_test, label_test = data['input_test'], data['label_test']
input_real = data['input_real']
lb, ub = data['lb'], data['ub']
label_name = data['label_name']

R_train, R_test = input_train.shape[0], input_test.shape[0] # num of train/test 'samples'
R = R_train + R_test
M, L = input_train.shape[1], label_train.shape[1]

if args.learn_standard_error:   # sd as labels
    label_train = np.hstack([label_train, np.zeros((R_train, L))])
    label_test = np.hstack([label_test, np.zeros((R_test, L))])
    output_dim = 2 * L
else:
    output_dim = L

scaler = StandardScaler()
input_train, input_test = scaler.fit_transform(input_train), scaler.fit_transform(input_test)
input_real = scaler.fit_transform(input_real.reshape(1, -1))


# Dataset and DataLoader
train_dataset = TensorDataset(torch.tensor(input_train, dtype=torch.float32),
                                torch.tensor(label_train, dtype=torch.float32))
train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)
net = NeuralNet(M, args.num_nodes, output_dim)

device = torch.device("cpu")
net.to(device)
if args.learn_standard_error:
    criterion = forward_loss
else:
    criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=args.initial_lr)

# Optional: learning rate scheduler similar to MATLAB piecewise schedule
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.1) # 40, 0.1

for epoch in range(args.max_epochs):
    net.train()
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = net(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()

    scheduler.step()

# Validation / Test summary (optional)
    net.eval()
    with torch.no_grad():
        test_preds = net(torch.tensor(input_test, dtype=torch.float32))
        loss_va = criterion(test_preds, torch.tensor(label_test, dtype=torch.float32))

    if args.disp_iter:
        print(f"Epoch {epoch + 1}/{args.max_epochs}, Train Loss: {loss.item():.4f}, Val Loss: {loss_va.item():.4f}")
# Out:
# Epoch 1/100, Train Loss: 0.3587, Val Loss: 0.2939
# Epoch 2/100, Train Loss: 0.3583, Val Loss: 0.2746
# Epoch 3/100, Train Loss: 0.3622, Val Loss: 0.2574
# Epoch 4/100, Train Loss: 0.0738, Val Loss: 0.2212
# Epoch 5/100, Train Loss: 0.2316, Val Loss: 0.2317
# Epoch 6/100, Train Loss: 0.1349, Val Loss: 0.2133
# Epoch 7/100, Train Loss: 0.2241, Val Loss: 0.2068
# Epoch 8/100, Train Loss: 0.1460, Val Loss: 0.1928
# Epoch 9/100, Train Loss: 0.1447, Val Loss: 0.2041
# Epoch 10/100, Train Loss: 0.2498, Val Loss: 0.2014
# Epoch 11/100, Train Loss: 0.1803, Val Loss: 0.2155
# Epoch 12/100, Train Loss: 0.2710, Val Loss: 0.2845
# Epoch 13/100, Train Loss: 0.1907, Val Loss: 0.2090
# Epoch 14/100, Train Loss: 0.1702, Val Loss: 0.1970
# Epoch 15/100, Train Loss: 0.1471, Val Loss: 0.1913
# Epoch 16/100, Train Loss: 0.1488, Val Loss: 0.2054
# Epoch 17/100, Train Loss: 0.2397, Val Loss: 0.2349
# Epoch 18/100, Train Loss: 0.1494, Val Loss: 0.2216
# Epoch 19/100, Train Loss: 0.1784, Val Loss: 0.2109
# Epoch 20/100, Train Loss: 0.1254, Val Loss: 0.2110
# Epoch 21/100, Train Loss: 0.1494, Val Loss: 0.2598
# Epoch 22/100, Train Loss: 0.1545, Val Loss: 0.1769
# Epoch 23/100, Train Loss: 0.0948, Val Loss: 0.1898
# Epoch 24/100, Train Loss: 0.1623, Val Loss: 0.2205
# Epoch 25/100, Train Loss: 0.1635, Val Loss: 0.1877
# Epoch 26/100, Train Loss: 0.1831, Val Loss: 0.2122
# Epoch 27/100, Train Loss: 0.1021, Val Loss: 0.2441
# Epoch 28/100, Train Loss: 0.0952, Val Loss: 0.1859
# Epoch 29/100, Train Loss: 0.2056, Val Loss: 0.1525
# Epoch 30/100, Train Loss: 0.0820, Val Loss: 0.1875
# Epoch 31/100, Train Loss: 0.2115, Val Loss: 0.2353
# Epoch 32/100, Train Loss: 0.1182, Val Loss: 0.2264
# Epoch 33/100, Train Loss: 0.2141, Val Loss: 0.1741
# Epoch 34/100, Train Loss: 0.0841, Val Loss: 0.2093
# Epoch 35/100, Train Loss: 0.1641, Val Loss: 0.1754
# Epoch 36/100, Train Loss: 0.1407, Val Loss: 0.1867
# Epoch 37/100, Train Loss: 0.2069, Val Loss: 0.1822
# Epoch 38/100, Train Loss: 0.1434, Val Loss: 0.1910
# Epoch 39/100, Train Loss: 0.0834, Val Loss: 0.2027
# Epoch 40/100, Train Loss: 0.1641, Val Loss: 0.1913
# Epoch 41/100, Train Loss: 0.0743, Val Loss: 0.1361
# Epoch 42/100, Train Loss: 0.0809, Val Loss: 0.1406
# Epoch 43/100, Train Loss: 0.0382, Val Loss: 0.1380
# Epoch 44/100, Train Loss: 0.1253, Val Loss: 0.1385
# Epoch 45/100, Train Loss: 0.0324, Val Loss: 0.1353
# Epoch 46/100, Train Loss: 0.1055, Val Loss: 0.1455
# Epoch 47/100, Train Loss: 0.0725, Val Loss: 0.1603
# Epoch 48/100, Train Loss: 0.0779, Val Loss: 0.1439
# Epoch 49/100, Train Loss: 0.0314, Val Loss: 0.1382
# Epoch 50/100, Train Loss: 0.0608, Val Loss: 0.1368
# Epoch 51/100, Train Loss: 0.0591, Val Loss: 0.1366
# Epoch 52/100, Train Loss: 0.1022, Val Loss: 0.1304
# Epoch 53/100, Train Loss: 0.0590, Val Loss: 0.1445
# Epoch 54/100, Train Loss: 0.0645, Val Loss: 0.1413
# Epoch 55/100, Train Loss: 0.0482, Val Loss: 0.1424
# Epoch 56/100, Train Loss: 0.0831, Val Loss: 0.1435
# Epoch 57/100, Train Loss: 0.0609, Val Loss: 0.1665
# Epoch 58/100, Train Loss: 0.0914, Val Loss: 0.1415
# Epoch 59/100, Train Loss: 0.1313, Val Loss: 0.1389
# Epoch 60/100, Train Loss: 0.0656, Val Loss: 0.1516
# Epoch 61/100, Train Loss: 0.0793, Val Loss: 0.1328
# Epoch 62/100, Train Loss: 0.1023, Val Loss: 0.1471
# Epoch 63/100, Train Loss: 0.0547, Val Loss: 0.1273
# Epoch 64/100, Train Loss: 0.0994, Val Loss: 0.1485
# Epoch 65/100, Train Loss: 0.0576, Val Loss: 0.1532
# Epoch 66/100, Train Loss: 0.0892, Val Loss: 0.1516
# Epoch 67/100, Train Loss: 0.0567, Val Loss: 0.1374
# Epoch 68/100, Train Loss: 0.0503, Val Loss: 0.1528
# Epoch 69/100, Train Loss: 0.0602, Val Loss: 0.1585
# Epoch 70/100, Train Loss: 0.0415, Val Loss: 0.1304
# Epoch 71/100, Train Loss: 0.0616, Val Loss: 0.1395
# Epoch 72/100, Train Loss: 0.0588, Val Loss: 0.1364
# Epoch 73/100, Train Loss: 0.0572, Val Loss: 0.1372
# Epoch 74/100, Train Loss: 0.0367, Val Loss: 0.1436
# Epoch 75/100, Train Loss: 0.0516, Val Loss: 0.1473
# Epoch 76/100, Train Loss: 0.1069, Val Loss: 0.1553
# Epoch 77/100, Train Loss: 0.0310, Val Loss: 0.1525
# Epoch 78/100, Train Loss: 0.1527, Val Loss: 0.1375
# Epoch 79/100, Train Loss: 0.0967, Val Loss: 0.1362
# Epoch 80/100, Train Loss: 0.0875, Val Loss: 0.1375
# Epoch 81/100, Train Loss: 0.0515, Val Loss: 0.1406
# Epoch 82/100, Train Loss: 0.0316, Val Loss: 0.1412
# Epoch 83/100, Train Loss: 0.0353, Val Loss: 0.1408
# Epoch 84/100, Train Loss: 0.0568, Val Loss: 0.1398
# Epoch 85/100, Train Loss: 0.0658, Val Loss: 0.1425
# Epoch 86/100, Train Loss: 0.0482, Val Loss: 0.1405
# Epoch 87/100, Train Loss: 0.0668, Val Loss: 0.1423
# Epoch 88/100, Train Loss: 0.0726, Val Loss: 0.1422
# Epoch 89/100, Train Loss: 0.0368, Val Loss: 0.1406
# Epoch 90/100, Train Loss: 0.0254, Val Loss: 0.1417
# Epoch 91/100, Train Loss: 0.0762, Val Loss: 0.1409
# Epoch 92/100, Train Loss: 0.0412, Val Loss: 0.1413
# Epoch 93/100, Train Loss: 0.0197, Val Loss: 0.1423
# Epoch 94/100, Train Loss: 0.0607, Val Loss: 0.1416
# Epoch 95/100, Train Loss: 0.0478, Val Loss: 0.1396
# Epoch 96/100, Train Loss: 0.0871, Val Loss: 0.1396
# Epoch 97/100, Train Loss: 0.0442, Val Loss: 0.1384
# Epoch 98/100, Train Loss: 0.0859, Val Loss: 0.1422
# Epoch 99/100, Train Loss: 0.0500, Val Loss: 0.1399
# Epoch 100/100, Train Loss: 0.0239, Val Loss: 0.1399

# %%
# %matplotlib inline

# %%
# 采样部分样本，保证计算速度
bg_n = min(len(input_train), max(1, 250))
ev_n = len(input_test)
bg_idx = np.random.choice(len(input_train), size=bg_n, replace=False)
ev_idx = np.random.choice(len(input_test), size=ev_n, replace=False)
background = torch.tensor(input_train[bg_idx], dtype=torch.float32)
eval_x = torch.tensor(input_test[ev_idx], dtype=torch.float32)

net.eval()
with torch.no_grad():
    pred_dim = net(eval_x[:1]).shape[1]

target_idx = int(np.clip(0, 0, pred_dim - 1))
explainer = shap.DeepExplainer(net, background)
shap_values = explainer.shap_values(eval_x)

# %%
if isinstance(shap_values, list):
    # Multi-output model: pick one output dimension to explain.
    shap_matrix = np.array(shap_values[target_idx])
else:
    shap_matrix = np.array(shap_values)
    if shap_matrix.ndim == 3:
        shap_matrix = shap_matrix[:, :, target_idx]

importance = np.mean(np.abs(shap_matrix), axis=0)
order = np.argsort(-importance)
top_k = min(max(1, 15), len(importance))

print(f"\nSHAP feature importance (target output idx={target_idx}, top {top_k}):")
for rank, feat_idx in enumerate(order[:top_k], start=1):
    print(f"{rank:>2}. x{feat_idx:<3} | mean(|SHAP|) = {importance[feat_idx]:.6g}")
# Out:
# SHAP feature importance (target output idx=0, top 15):
#  1. x26  | mean(|SHAP|) = 1.05053
#  2. x12  | mean(|SHAP|) = 0.416185
#  3. x9   | mean(|SHAP|) = 0.375184
#  4. x25  | mean(|SHAP|) = 0.371674
#  5. x16  | mean(|SHAP|) = 0.367198
#  6. x13  | mean(|SHAP|) = 0.254801
#  7. x35  | mean(|SHAP|) = 0.191369
#  8. x4   | mean(|SHAP|) = 0.168293
#  9. x14  | mean(|SHAP|) = 0.155042
# 10. x19  | mean(|SHAP|) = 0.151692
# 11. x15  | mean(|SHAP|) = 0.135579
# 12. x10  | mean(|SHAP|) = 0.134388
# 13. x33  | mean(|SHAP|) = 0.123351
# 14. x32  | mean(|SHAP|) = 0.108236
# 15. x21  | mean(|SHAP|) = 0.0938913

# %%
shap_values.shape, eval_x.shape
# Out:
# ((1000, 38, 7), torch.Size([1000, 38]))

# %%
import pandas as pd
feature_names = ["μ(deg)p1", "V(deg)p1", "μ(x)p1", "V(x)p1", "clu_coeff_p1",
                 "μ(deg)p2", "V(deg)p2", "μ(x)p2", "V(x)p2", "clu_coeff_p2",
                 "Y(t-1)|Yijt=1", "Dist|Yijt=1", "LogDegSum|Yijt=1", "Cos(X)|Yijt=1", 
                 "V[Y(t-1)|Yijt=1]", "Cov[Y(t-1),Dist|Yijt=1]", "Cov[Y(t-1),LogDegSum|Yijt=1]", "Cov[Y(t-1),Cos(X)|Yijt=1]",
                 "V[Dist|Yijt=1]","Cov[Dist,LogDegSum|Yijt=1]", "Cov[Dist,Cos(X)|Yijt=1]","V[LogDegSum|Yijt=1]","Cov[LogDegSum,Cos(X)|Yijt=1]","V[Cos(X)|Yijt=1]",
                 "Y(t-1)|Yijt=0", "Dist|Yijt=0", "LogDegSum|Yijt=0", "Cos(X)|Yijt=0", 
                 "V[Y(t-1)|Yijt=0]", "Cov[Y(t-1),Dist|Yijt=0]", "Cov[Y(t-1),LogDegSum|Yijt=0]", "Cov[Y(t-1),Cos(X)|Yijt=0]",
                 "V[Dist|Yijt=0]","Cov[Dist,LogDegSum|Yijt=0]", "Cov[Dist,Cos(X)|Yijt=0]","V[LogDegSum|Yijt=0]","Cov[LogDegSum,Cos(X)|Yijt=0]","V[Cos(X)|Yijt=0]",] 
eval_x_df = pd.DataFrame(eval_x, columns=feature_names)

# %%
fig, axes = plt.subplots(1, 7, figsize=(28, 5), constrained_layout=True)
titles = [
    r'Overall Moment Ipt.: ${c}$',
    r'Overall Moment Ipt.: ${\alpha}$',
    r'Overall Moment Ipt.: ${\beta}$',
    r'Overall Moment Ipt.: ${\delta}$',
    r'Overall Moment Ipt.: ${\lambda}$',
    r'Overall Moment Ipt.: ${\gamma}$',
    r'Overall Moment Ipt.: ${\tau}$'
]
for i, ax in enumerate(axes):
    plt.sca(ax)  # 明确当前子图
    shap.summary_plot(
        shap_values[:, :, i],
        eval_x_df,
        plot_type="bar",
        show=False,
        plot_size=None,   # 很关键：不要让 SHAP 自己改图大小
        max_display=10    # 可选：减少标签数量，避免拥挤
    )
    ax.set_title(titles[i], fontname="Times New Roman", fontweight="bold", fontsize=12)
    ax.set_xlabel("")

    for lab in ax.get_xticklabels() + ax.get_yticklabels():
        lab.set_fontname("Times New Roman")
        lab.set_fontweight("bold")
        lab.set_fontsize(10)
plt.show()

# %%
fig, axes = plt.subplots(1, 7, figsize=(28, 5), constrained_layout=True)
titles = [
    r'Sample Moment Ipt.: ${c}$',
    r'Sample Moment Ipt.: ${\alpha}$',
    r'Sample Moment Ipt.: ${\beta}$',
    r'Sample Moment Ipt.: ${\delta}$',
    r'Sample Moment Ipt.: ${\lambda}$',
    r'Sample Moment Ipt.: ${\gamma}$',
    r'Sample Moment Ipt.: ${\tau}$'
]
for i, ax in enumerate(axes):
    Enable_color_bar = True if i==6 else False
    plt.sca(ax)  # 明确当前子图
    shap.summary_plot(
        shap_values[:, :, i],
        eval_x_df,
        plot_type="dot",
        show=False,
        plot_size=None,   # 很关键：不要让 SHAP 自己改图大小
        color_bar=Enable_color_bar,
        max_display=10    # 可选：减少标签数量，避免拥挤
    )
    ax.set_title(titles[i], fontname="Times New Roman", fontweight="bold", fontsize=12)
    ax.set_xlabel("")

    for lab in ax.get_xticklabels() + ax.get_yticklabels():
        lab.set_fontname("Times New Roman")
        lab.set_fontweight("bold")
        lab.set_fontsize(10)
plt.show()

# %%
# 3. 依赖关系图
check_feature_index = 'Dist|Yijt=0'
shap.dependence_plot(
    check_feature_index, # top_feature_idx
    shap_values[:, :, 3], # parameter δ
    eval_x_df,  # shape (256, 38)
    interaction_index = 'LogDegSum|Yijt=0'
)


'''
解读：
1、Dist|Yijt=0和LogDegSum|Yijt=0两个特征为负相关关系，前者增加则后者减少
2、影响程度：Dist|Yijt=0在0-1之间，ShAP值增长最快，说明该取值部分对于结果影响最大
3、交互效果：x轴、颜色及y轴关系代表两个特征及目标变量之间的交互关系
'''

# %%
#  4. 单样本力图
# 选取 eval_x 中的第一个样本进行解释
sample_idx = 0
sample_data = eval_x[sample_idx:sample_idx+1,:]
sample_shap = shap_matrix[sample_idx:sample_idx+1,:]

# base value（多输出时取 target_idx）
base = explainer.expected_value
if isinstance(base, (list, tuple, np.ndarray)):
    base_value = float(np.array(base).reshape(-1)[target_idx])
else:
    base_value = float(base)


shap.force_plot(
    base_value,          # 第一个参数必须是 base value
    sample_shap.flatten(),         # 该样本的 SHAP 向量 (38)
    sample_data.numpy().flatten(),         # 该样本特征 torch.Size([38])
    matplotlib=True,
)

# %%
# 5. 热力图
# 为了可视化效果，通常只对最重要的特征画图
top_k_features = 20
top_indices = order[:top_k_features]

# 提取子矩阵
shap_matrix_subset = shap_matrix[:, top_indices]

plt.figure(figsize=(12, 8))
# 对样本进行聚类或排序（可选，这里按 SHAP 值总和排序以便观察）
row_order = np.argsort(np.sum(np.abs(shap_matrix_subset), axis=1))[::-1]

sns.heatmap(shap_matrix_subset[row_order], 
            cmap="RdBu_r", # 红蓝配色，红正蓝负
            center=0,
            xticklabels=[f"x{i}" for i in top_indices],
            yticklabels=False) # 样本太多时不显示 y 轴标签

plt.xlabel("Features")
plt.ylabel("Samples (Sorted)")
plt.title(f"SHAP Values Heatmap (Top {top_k_features} Features)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Other importance check

# %%
with open('simu_data_collect/model2/training_set_gen.pkl', 'rb') as f:
#with open('training_set_gen.pkl', 'rb') as f:  # data from "set_up.py"
    data = pickle.load(f)
set_train_seed(101)

# %%
# load training/validation/real data
input_train, label_train = data['input_train'], data['label_train']
input_test, label_test = data['input_test'], data['label_test']
input_real = data['input_real']
lb, ub = data['lb'], data['ub']
label_name = data['label_name']

# %%
'''
Moment list:
1. (mean_deg, var_deg, clusterglobal)*period,
2. (mean(y_ijt, x_ij,t-1), cov(y_ijt, x_ij,t-1))*period,
x_ij,t-1 = (y_ij,t-1, SumDegree_ij,t-1, NetDistanceij,t-1)
3. zi (feature)
'''

print(input_train.shape, input_test.shape, input_real.shape) # (n_samples, moment_dim), (n_samples, moment_dim), (moment_dim,)
# Out:
# (900, 31) (100, 31) (31,)

# %%
R_train, R_test = input_train.shape[0], input_test.shape[0] # num of train/test 'samples'
R = R_train + R_test
M, L = input_train.shape[1], label_train.shape[1]

if args.learn_standard_error:   # sd as labels
    label_train = np.hstack([label_train, np.zeros((R_train, L))])
    label_test = np.hstack([label_test, np.zeros((R_test, L))])
    output_dim = 2 * L
else:
    output_dim = L

scaler = StandardScaler()
input_train, input_test = scaler.fit_transform(input_train), scaler.fit_transform(input_test)
input_real = scaler.fit_transform(input_real.reshape(1, -1))

# Dataset and DataLoader
train_dataset = TensorDataset(torch.tensor(input_train, dtype=torch.float32),
                              torch.tensor(label_train, dtype=torch.float32))
train_loader = DataLoader(train_dataset, batch_size=args.batch_size, shuffle=True)
net = NeuralNet(M, args.num_nodes, output_dim)


device = torch.device("cpu")
net.to(device)
if args.learn_standard_error:
    criterion = forward_loss
else:
    criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=args.initial_lr)

# Optional: learning rate scheduler similar to MATLAB piecewise schedule
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=40, gamma=0.1) # 40, 0.1

for epoch in range(args.max_epochs):
    net.train()
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = net(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()

    scheduler.step()

# Validation / Test summary (optional)
    net.eval()
    with torch.no_grad():
        test_preds = net(torch.tensor(input_test, dtype=torch.float32))
        loss_va = criterion(test_preds, torch.tensor(label_test, dtype=torch.float32))

    if args.disp_iter:
        print(f"Epoch {epoch + 1}/{args.max_epochs}, Train Loss: {loss.item():.4f}, Val Loss: {loss_va.item():.4f}")


if args.disp_test_summary:
    net.eval()
    with torch.no_grad():
        test_preds = net(torch.tensor(input_test, dtype=torch.float32))
        Test_error_summary(torch.tensor(input_test, dtype=torch.float32), label_test, label_name, net, figure=args.display_fig, table=1)

# Estimate on original data
net.eval()
with torch.no_grad():
    temp = net(torch.tensor(input_real.squeeze(0), dtype=torch.float32)).numpy()

# 截断 theta
theta = np.clip(temp[:L], lb, ub)

# 正向变换标准误（如果学习）
if args.learn_standard_error:
    se = Positive_transform(temp[L:2 * L])

print(theta)
print(se)
# Out:
# Epoch 1/200, Train Loss: 133.5827, Val Loss: 114.0630
# Epoch 2/200, Train Loss: 77.7617, Val Loss: 341.9515
# Epoch 3/200, Train Loss: 78.4388, Val Loss: 65.8587
# Epoch 4/200, Train Loss: 59.3914, Val Loss: 50.5181
# Epoch 5/200, Train Loss: 74.1005, Val Loss: 47.6608
# Epoch 6/200, Train Loss: 22.7167, Val Loss: 42.6580
# Epoch 7/200, Train Loss: 7.0540, Val Loss: 40.3200
# Epoch 8/200, Train Loss: 57.6607, Val Loss: 38.3525
# Epoch 9/200, Train Loss: 23.6220, Val Loss: 39.3016
# Epoch 10/200, Train Loss: 33.8099, Val Loss: 40.3671
# Epoch 11/200, Train Loss: 0.2291, Val Loss: 38.9996
# Epoch 12/200, Train Loss: 25.6668, Val Loss: 36.6207
# Epoch 13/200, Train Loss: 36.5096, Val Loss: 42.0711
# Epoch 14/200, Train Loss: 37.9546, Val Loss: 36.9787
# Epoch 15/200, Train Loss: 7.7854, Val Loss: 43.7293
# Epoch 16/200, Train Loss: 20.2997, Val Loss: 46.7072
# Epoch 17/200, Train Loss: 30.7493, Val Loss: 49.1016
# Epoch 18/200, Train Loss: 40.8090, Val Loss: 43.2020
# Epoch 19/200, Train Loss: 52.7868, Val Loss: 38.8965
# Epoch 20/200, Train Loss: 72.5331, Val Loss: 46.7042
# Epoch 21/200, Train Loss: 59.7429, Val Loss: 40.2520
# Epoch 22/200, Train Loss: 7.7660, Val Loss: 40.8249
# Epoch 23/200, Train Loss: 38.5799, Val Loss: 45.3814
# Epoch 24/200, Train Loss: 15.7995, Val Loss: 37.2489
# Epoch 25/200, Train Loss: 28.8934, Val Loss: 41.4350
# Epoch 26/200, Train Loss: 7.8945, Val Loss: 38.9225
# Epoch 27/200, Train Loss: 25.5933, Val Loss: 33.4847
# Epoch 28/200, Train Loss: 60.2915, Val Loss: 40.3736
# Epoch 29/200, Train Loss: 24.3770, Val Loss: 39.9529
# Epoch 30/200, Train Loss: 15.0796, Val Loss: 36.3601
# Epoch 31/200, Train Loss: 19.4159, Val Loss: 36.9583
# Epoch 32/200, Train Loss: 46.4147, Val Loss: 39.1352
# Epoch 33/200, Train Loss: 6.7183, Val Loss: 37.5878
# Epoch 34/200, Train Loss: 61.9689, Val Loss: 34.6499
# Epoch 35/200, Train Loss: 36.1883, Val Loss: 33.9243
# Epoch 36/200, Train Loss: 26.5705, Val Loss: 31.5025
# Epoch 37/200, Train Loss: 44.8806, Val Loss: 33.1280
# Epoch 38/200, Train Loss: 30.2839, Val Loss: 34.4621
# Epoch 39/200, Train Loss: 24.0983, Val Loss: 37.7991
# Epoch 40/200, Train Loss: 59.1360, Val Loss: 36.2669
# Epoch 41/200, Train Loss: 31.5791, Val Loss: 34.8823
# Epoch 42/200, Train Loss: -2.4402, Val Loss: 31.9972
# Epoch 43/200, Train Loss: 32.1857, Val Loss: 33.0274
# Epoch 44/200, Train Loss: 42.3005, Val Loss: 33.0425
# Epoch 45/200, Train Loss: 49.7090, Val Loss: 31.8323
# Epoch 46/200, Train Loss: 3.6265, Val Loss: 33.0383
# Epoch 47/200, Train Loss: 7.3165, Val Loss: 32.7163
# Epoch 48/200, Train Loss: 16.7047, Val Loss: 31.8621
# Epoch 49/200, Train Loss: 17.2469, Val Loss: 32.3946
# Epoch 50/200, Train Loss: 2.6822, Val Loss: 32.1306
# Epoch 51/200, Train Loss: 17.9643, Val Loss: 32.2699
# Epoch 52/200, Train Loss: 16.3472, Val Loss: 32.4714
# Epoch 53/200, Train Loss: 38.6189, Val Loss: 32.1132
# Epoch 54/200, Train Loss: 34.7250, Val Loss: 31.8234
# Epoch 55/200, Train Loss: -0.3390, Val Loss: 31.7821
# Epoch 56/200, Train Loss: 27.7788, Val Loss: 31.9784
# Epoch 57/200, Train Loss: 35.3293, Val Loss: 31.5367
# Epoch 58/200, Train Loss: 5.7262, Val Loss: 32.1214
# Epoch 59/200, Train Loss: 23.8154, Val Loss: 31.7148
# Epoch 60/200, Train Loss: 15.4079, Val Loss: 32.3187
# Epoch 61/200, Train Loss: 45.6538, Val Loss: 31.5798
# Epoch 62/200, Train Loss: 15.8384, Val Loss: 32.5826
# Epoch 63/200, Train Loss: 22.8032, Val Loss: 31.9449
# Epoch 64/200, Train Loss: 37.1762, Val Loss: 31.9508
# Epoch 65/200, Train Loss: 29.8160, Val Loss: 32.7056
# Epoch 66/200, Train Loss: 5.4345, Val Loss: 32.2784
# Epoch 67/200, Train Loss: 29.5794, Val Loss: 31.9127
# Epoch 68/200, Train Loss: 42.4163, Val Loss: 32.9004
# Epoch 69/200, Train Loss: 11.1567, Val Loss: 32.4760
# Epoch 70/200, Train Loss: 10.8994, Val Loss: 31.9359
# Epoch 71/200, Train Loss: 19.3348, Val Loss: 32.6772
# Epoch 72/200, Train Loss: 42.1639, Val Loss: 31.5172
# Epoch 73/200, Train Loss: 40.1566, Val Loss: 32.6472
# Epoch 74/200, Train Loss: 31.7814, Val Loss: 32.6480
# Epoch 75/200, Train Loss: 5.5437, Val Loss: 32.6279
# Epoch 76/200, Train Loss: 62.7189, Val Loss: 32.3814
# Epoch 77/200, Train Loss: 21.9792, Val Loss: 33.4744
# Epoch 78/200, Train Loss: 11.2413, Val Loss: 32.0091
# Epoch 79/200, Train Loss: 15.7931, Val Loss: 32.0949
# Epoch 80/200, Train Loss: 35.6967, Val Loss: 32.6239
# Epoch 81/200, Train Loss: 17.5645, Val Loss: 32.3099
# Epoch 82/200, Train Loss: 17.1264, Val Loss: 32.0993
# Epoch 83/200, Train Loss: 24.5196, Val Loss: 32.2744
# Epoch 84/200, Train Loss: 35.6160, Val Loss: 32.0669
# Epoch 85/200, Train Loss: 17.5166, Val Loss: 32.3575
# Epoch 86/200, Train Loss: 26.3339, Val Loss: 32.4927
# Epoch 87/200, Train Loss: 41.4269, Val Loss: 32.3598
# Epoch 88/200, Train Loss: 15.7002, Val Loss: 31.9850
# Epoch 89/200, Train Loss: 16.4230, Val Loss: 32.0944
# Epoch 90/200, Train Loss: 60.2454, Val Loss: 32.0976
# Epoch 91/200, Train Loss: 38.8333, Val Loss: 31.5330
# Epoch 92/200, Train Loss: 27.3443, Val Loss: 31.7281
# Epoch 93/200, Train Loss: 3.8812, Val Loss: 31.7336
# Epoch 94/200, Train Loss: 15.3631, Val Loss: 31.6183
# Epoch 95/200, Train Loss: 34.5561, Val Loss: 31.6642
# Epoch 96/200, Train Loss: 35.2519, Val Loss: 31.4852
# Epoch 97/200, Train Loss: 17.6063, Val Loss: 31.4298
# Epoch 98/200, Train Loss: 8.0865, Val Loss: 31.7370
# Epoch 99/200, Train Loss: 2.0918, Val Loss: 31.9931
# Epoch 100/200, Train Loss: 15.8973, Val Loss: 31.9987
# Epoch 101/200, Train Loss: 17.2154, Val Loss: 32.1407
# Epoch 102/200, Train Loss: 54.4982, Val Loss: 32.2227
# Epoch 103/200, Train Loss: 9.8585, Val Loss: 32.0286
# Epoch 104/200, Train Loss: 15.3185, Val Loss: 32.1397
# Epoch 105/200, Train Loss: 37.9989, Val Loss: 32.0489
# Epoch 106/200, Train Loss: 22.5803, Val Loss: 32.1090
# Epoch 107/200, Train Loss: 17.4291, Val Loss: 31.7700
# Epoch 108/200, Train Loss: 15.0954, Val Loss: 31.9810
# Epoch 109/200, Train Loss: 33.3087, Val Loss: 32.0169
# Epoch 110/200, Train Loss: 5.2022, Val Loss: 31.7601
# Epoch 111/200, Train Loss: 42.6701, Val Loss: 31.9772
# Epoch 112/200, Train Loss: 25.2471, Val Loss: 32.3298
# Epoch 113/200, Train Loss: 7.3423, Val Loss: 32.0078
# Epoch 114/200, Train Loss: 41.5003, Val Loss: 31.9246
# Epoch 115/200, Train Loss: 17.6830, Val Loss: 31.9246
# Epoch 116/200, Train Loss: 8.9695, Val Loss: 31.8424
# Epoch 117/200, Train Loss: 17.5405, Val Loss: 31.8056
# Epoch 118/200, Train Loss: 7.0188, Val Loss: 31.7117
# Epoch 119/200, Train Loss: 4.0550, Val Loss: 32.0029
# Epoch 120/200, Train Loss: -0.3117, Val Loss: 31.8499
# Epoch 121/200, Train Loss: 23.9629, Val Loss: 31.8419
# Epoch 122/200, Train Loss: 9.8052, Val Loss: 31.8425
# Epoch 123/200, Train Loss: 14.8753, Val Loss: 31.8452
# Epoch 124/200, Train Loss: 59.6467, Val Loss: 31.8357
# Epoch 125/200, Train Loss: 69.0241, Val Loss: 31.8347
# Epoch 126/200, Train Loss: 26.0282, Val Loss: 31.8267
# Epoch 127/200, Train Loss: 39.2383, Val Loss: 31.8143
# Epoch 128/200, Train Loss: 22.2494, Val Loss: 31.8269
# Epoch 129/200, Train Loss: 22.8609, Val Loss: 31.8537
# Epoch 130/200, Train Loss: 87.5677, Val Loss: 31.8552
# Epoch 131/200, Train Loss: 28.7860, Val Loss: 31.8596
# Epoch 132/200, Train Loss: 1.0943, Val Loss: 31.8404
# Epoch 133/200, Train Loss: 16.4190, Val Loss: 31.8383
# Epoch 134/200, Train Loss: 11.6754, Val Loss: 31.8119
# Epoch 135/200, Train Loss: 12.0867, Val Loss: 31.8095
# Epoch 136/200, Train Loss: 23.5945, Val Loss: 31.8300
# Epoch 137/200, Train Loss: 27.3843, Val Loss: 31.7955
# Epoch 138/200, Train Loss: 11.4089, Val Loss: 31.7569
# Epoch 139/200, Train Loss: 27.6809, Val Loss: 31.7310
# Epoch 140/200, Train Loss: 30.6534, Val Loss: 31.7635
# Epoch 141/200, Train Loss: 11.7347, Val Loss: 31.8005
# Epoch 142/200, Train Loss: 5.7950, Val Loss: 31.7846
# Epoch 143/200, Train Loss: 39.1973, Val Loss: 31.7773
# Epoch 144/200, Train Loss: 21.2128, Val Loss: 31.8115
# Epoch 145/200, Train Loss: 19.1305, Val Loss: 31.7912
# Epoch 146/200, Train Loss: 7.6575, Val Loss: 31.8205
# Epoch 147/200, Train Loss: 7.4454, Val Loss: 31.8071
# Epoch 148/200, Train Loss: 7.2860, Val Loss: 31.8081
# Epoch 149/200, Train Loss: 28.3679, Val Loss: 31.8074
# Epoch 150/200, Train Loss: -0.8063, Val Loss: 31.7897
# Epoch 151/200, Train Loss: -2.7779, Val Loss: 31.7796
# Epoch 152/200, Train Loss: 39.4791, Val Loss: 31.8140
# Epoch 153/200, Train Loss: 21.0622, Val Loss: 31.7652
# Epoch 154/200, Train Loss: 15.7732, Val Loss: 31.7278
# Epoch 155/200, Train Loss: 5.3152, Val Loss: 31.7132
# Epoch 156/200, Train Loss: 12.0423, Val Loss: 31.7129
# Epoch 157/200, Train Loss: 9.4772, Val Loss: 31.7148
# Epoch 158/200, Train Loss: 32.8757, Val Loss: 31.7449
# Epoch 159/200, Train Loss: 20.5404, Val Loss: 31.8014
# Epoch 160/200, Train Loss: 57.9989, Val Loss: 31.8304
# Epoch 161/200, Train Loss: 21.8766, Val Loss: 31.8340
# Epoch 162/200, Train Loss: 7.8705, Val Loss: 31.8380
# Epoch 163/200, Train Loss: 9.5140, Val Loss: 31.8371
# Epoch 164/200, Train Loss: 30.8373, Val Loss: 31.8352
# Epoch 165/200, Train Loss: 14.5687, Val Loss: 31.8370
# Epoch 166/200, Train Loss: 30.7995, Val Loss: 31.8410
# Epoch 167/200, Train Loss: 14.9440, Val Loss: 31.8451
# Epoch 168/200, Train Loss: 25.5204, Val Loss: 31.8476
# Epoch 169/200, Train Loss: 15.0210, Val Loss: 31.8475
# Epoch 170/200, Train Loss: 10.2776, Val Loss: 31.8456
# Epoch 171/200, Train Loss: 20.4075, Val Loss: 31.8441
# Epoch 172/200, Train Loss: 15.4502, Val Loss: 31.8412
# Epoch 173/200, Train Loss: 13.0308, Val Loss: 31.8415
# Epoch 174/200, Train Loss: 42.1007, Val Loss: 31.8431
# Epoch 175/200, Train Loss: 17.2316, Val Loss: 31.8437
# Epoch 176/200, Train Loss: 17.9906, Val Loss: 31.8409
# Epoch 177/200, Train Loss: 35.9332, Val Loss: 31.8382
# Epoch 178/200, Train Loss: 9.5159, Val Loss: 31.8352
# Epoch 179/200, Train Loss: 21.9542, Val Loss: 31.8345
# Epoch 180/200, Train Loss: 23.5512, Val Loss: 31.8382
# Epoch 181/200, Train Loss: 45.1889, Val Loss: 31.8415
# Epoch 182/200, Train Loss: 39.4726, Val Loss: 31.8509
# Epoch 183/200, Train Loss: 9.9549, Val Loss: 31.8524
# Epoch 184/200, Train Loss: 16.3735, Val Loss: 31.8526
# Epoch 185/200, Train Loss: 33.3047, Val Loss: 31.8493
# Epoch 186/200, Train Loss: 45.7972, Val Loss: 31.8540
# Epoch 187/200, Train Loss: 15.2111, Val Loss: 31.8557
# Epoch 188/200, Train Loss: 25.3664, Val Loss: 31.8561
# Epoch 189/200, Train Loss: 34.7193, Val Loss: 31.8616
# Epoch 190/200, Train Loss: 39.3481, Val Loss: 31.8649
# Epoch 191/200, Train Loss: 1.8455, Val Loss: 31.8597
# Epoch 192/200, Train Loss: 11.9927, Val Loss: 31.8599
# Epoch 193/200, Train Loss: 69.2983, Val Loss: 31.8613
# Epoch 194/200, Train Loss: 6.4820, Val Loss: 31.8676
# Epoch 195/200, Train Loss: 32.6284, Val Loss: 31.8656
# Epoch 196/200, Train Loss: 4.9758, Val Loss: 31.8594
# Epoch 197/200, Train Loss: 3.7566, Val Loss: 31.8585
# Epoch 198/200, Train Loss: 4.1438, Val Loss: 31.8571
# Epoch 199/200, Train Loss: 31.2488, Val Loss: 31.8555
# Epoch 200/200, Train Loss: 13.2913, Val Loss: 31.8529
# Test results:                    bias         rmse      mean_SD
# \lambda_f   0.037 (0.1)  0.770 (0.1)  0.465 (0.0)
# \alpha_f   -0.511 (0.1)  1.161 (0.1)  0.681 (0.0)
# \beta_f     0.015 (0.1)  0.525 (0.0)  0.907 (0.0)
# \delta_f    0.178 (0.2)  2.374 (0.2)  0.408 (0.0)
# \theta_f    0.027 (0.0)  0.185 (0.0)  0.427 (0.0)
# \gamma_f   -0.085 (0.0)  0.244 (0.0)  0.461 (0.0)
# \tau       -0.073 (0.1)  1.081 (0.1)  0.640 (0.0)
# [-5.9075489   9.2110405   0.77698827  3.42420888  0.63840091  0.61024439
#   2.71588516]
# [0.5098519  0.7983891  0.8271841  0.3964754  0.3915194  0.49288756
#  0.6305784 ]

# %%
# feature importance analysis

# ==================== 特征重要性评估模块 ====================
import numpy as np
import matplotlib.pyplot as plt
import torch
from typing import List, Optional, Tuple

class FeatureImportanceAnalyzer:
    def __init__(self, model, device='cpu'):
        self.model = model
        self.device = device
        self.model.eval()
    
    def permutation_importance(self, X: np.ndarray, y: np.ndarray, criterion, 
                              feature_names: Optional[List[str]] = None, 
                              n_repeats: int = 10) -> Tuple[np.ndarray, np.ndarray]:
        """
        排列重要性：随机打乱单个特征，观察模型性能下降程度
        最可靠，计算稍慢但模型无关
        
        Args:
            X: 输入特征 (N, M)
            y: 标签 (N, L) 或 (N,)
            criterion: 损失函数 (如 nn.MSELoss())
            feature_names: 特征名称列表
            n_repeats: 重复次数（减少随机性）
        
        Returns:
            importance_mean: 平均重要性 (%)
            importance_std: 标准差 (%)
        """
        X_tensor = torch.tensor(X, dtype=torch.float32, device=self.device)
        y_tensor = torch.tensor(y, dtype=torch.float32, device=self.device)
        
        # 计算基准性能
        with torch.no_grad():
            baseline_pred = self.model(X_tensor)
            baseline_loss = criterion(baseline_pred, y_tensor).item()
        
        n_features = X.shape[1]
        importances = np.zeros((n_repeats, n_features))
        
        for r in range(n_repeats):
            for i in range(n_features):
                X_permuted = X.copy()
                # 随机打乱第i列（特征）
                perm_idx = np.random.permutation(X.shape[0])
                X_permuted[:, i] = X_permuted[perm_idx, i]
                
                X_perm_tensor = torch.tensor(X_permuted, dtype=torch.float32, device=self.device)
                
                with torch.no_grad():
                    pred = self.model(X_perm_tensor)
                    perm_loss = criterion(pred, y_tensor).item()
                
                # 重要性 = 性能下降幅度 (越大越重要)
                importances[r, i] = perm_loss - baseline_loss
        
        # 计算统计数据
        importance_mean = np.mean(importances, axis=0)
        importance_std = np.std(importances, axis=0)
        
        # 归一化为百分比 (0-100)
        if np.sum(importance_mean) > 0:
            importance_mean = importance_mean / np.sum(importance_mean) * 100
            importance_std = importance_std / np.sum(importance_mean) * 100
        
        return importance_mean, importance_std
    
    def gradient_importance(self, X: np.ndarray, feature_names: Optional[List[str]] = None) -> np.ndarray:
        """
        梯度重要性：计算输入特征的梯度绝对值平均
        速度快，但仅反映局部敏感性
        
        Args:
            X: 输入特征
            feature_names: 特征名称
        
        Returns:
            importance: 重要性数组 (%)
        """
        X_tensor = torch.tensor(X, dtype=torch.float32, device=self.device, requires_grad=True)
        
        self.model.zero_grad()
        output = self.model(X_tensor)
        
        # 对多输出回归，计算各输出绝对梯度的均值
        if output.shape[1] > 1:
            # 计算每个样本输出的均值，然后求梯度
            loss = output.mean()
        else:
            loss = output.mean()
        
        loss.backward()
        
        # 取梯度绝对值的平均
        grads = X_tensor.grad.abs().mean(dim=0).cpu().numpy()
        
        # 归一化
        importance = grads / np.sum(grads) * 100
        
        return importance
    
    def analyze(self, X: np.ndarray, y: np.ndarray, criterion, method: str = 'permutation',
                feature_names: Optional[List[str]] = None, n_repeats: int = 10,
                display: bool = True, save_path: Optional[str] = None) -> dict:
        """
        主分析函数
        
        Args:
            method: 'permutation', 'gradient', 或 'both'
            display: 是否显示图表
            save_path: 保存图表路径 (.png)
        """
        if feature_names is None:
            feature_names = [f'Feature_{i}' for i in range(X.shape[1])]
        
        results = {}
        
        if method in ['permutation', 'both']:
            perm_mean, perm_std = self.permutation_importance(X, y, criterion, feature_names, n_repeats)
            results['permutation_mean'] = perm_mean
            results['permutation_std'] = perm_std
        
        if method in ['gradient', 'both']:
            grad_imp = self.gradient_importance(X, feature_names)
            results['gradient'] = grad_imp
        
        # 可视化
        if display:
            self._plot_importance(results, feature_names, method, save_path)
        
        # 打印排名
        self._print_ranking(results, feature_names, method)
        
        return results
    
    def _plot_importance(self, results: dict, feature_names: List[str], method: str, save_path: Optional[str]):
        """绘制特征重要性图表"""
        n_methods = (1 if 'permutation_mean' in results else 0) + (1 if 'gradient' in results else 0)
        fig, axes = plt.subplots(1, n_methods, figsize=(6*n_methods, 5))
        if n_methods == 1:
            axes = [axes]
        
        idx = 0
        
        # 排列重要性
        if 'permutation_mean' in results:
            imp = results['permutation_mean']
            std = results.get('permutation_std', None)
            indices = np.argsort(imp)[::-1]
            
            ax = axes[idx]
            y_pos = np.arange(len(feature_names))
            ax.barh(y_pos, imp[indices], xerr=std[indices] if std is not None else None, 
                   capsize=3, alpha=0.7, color='skyblue', edgecolor='navy')
            ax.set_yticks(y_pos)
            ax.set_yticklabels([feature_names[i] for i in indices])
            ax.invert_yaxis()
            ax.set_xlabel('Importance (%)')
            ax.set_title('Permutation Importance\n(Higher = More Important)')
            ax.grid(axis='x', alpha=0.3)
            idx += 1
        
        # 梯度重要性
        if 'gradient' in results:
            imp = results['gradient']
            indices = np.argsort(imp)[::-1]
            
            ax = axes[idx]
            y_pos = np.arange(len(feature_names))
            ax.barh(y_pos, imp[indices], alpha=0.7, color='lightcoral', edgecolor='darkred')
            ax.set_yticks(y_pos)
            ax.set_yticklabels([feature_names[i] for i in indices])
            ax.invert_yaxis()
            ax.set_xlabel('Importance (%)')
            ax.set_title('Gradient Importance\n(Local Sensitivity)')
            ax.grid(axis='x', alpha=0.3)
        
        plt.tight_layout()
        
        if save_path:
            plt.savefig(save_path, dpi=300, bbox_inches='tight')
            print(f"特征重要性图已保存至: {save_path}")
        
        if args.display_fig:
            plt.show()
        else:
            plt.close()
    
    def _print_ranking(self, results: dict, feature_names: List[str], method: str):
        """打印重要性排名"""
        print("\n" + "="*50)
        print("特征重要性评估结果")
        print("="*50)
        
        if 'permutation_mean' in results:
            print("\n【排列重要性 - Permutation Importance】")
            print("原理：打乱该特征后模型性能下降越多，特征越重要")
            perm_imp = results['permutation_mean']
            perm_std = results.get('permutation_std', np.zeros_like(perm_imp))
            indices = np.argsort(perm_imp)[::-1]
            
            for rank, idx in enumerate(indices, 1):
                print(f"  {rank}. {feature_names[idx]:15s}: {perm_imp[idx]:6.2f}% ± {perm_std[idx]:5.2f}%")
        
        if 'gradient' in results:
            print("\n【梯度重要性 - Gradient Importance】")
            print("原理：输入梯度越大，输出对该特征越敏感")
            grad_imp = results['gradient']
            indices = np.argsort(grad_imp)[::-1]
            
            for rank, idx in enumerate(indices, 1):
                print(f"  {rank}. {feature_names[idx]:15s}: {grad_imp[idx]:6.2f}%")
        print("="*50)


# ==================== 使用示例（放在你的代码末尾） ====================

# 1. 初始化分析器
analyzer = FeatureImportanceAnalyzer(net, device)

# 2. 定义特征名称（可选，建议根据实际问题定义）
feature_names = [f'Input_{i+1}' for i in range(M)]  # 或自定义名称如 ['温度', '压力', '流量', ...]

# 3. 执行分析（推荐 method='permutation' 或 'both'）
# 注意：使用 label_test 作为目标，如果 label_test 是二维的，criterion 需要能处理
results = analyzer.analyze(
    X=input_test,
    y=label_test,
    criterion=criterion,
    method='both',              # 'permutation', 'gradient', 或 'both'
    feature_names=feature_names,
    n_repeats=10,               # 排列重复次数（越多越稳定，但越慢）
    display=True,               # 是否显示图表
    save_path='feature_importance.png'  # 保存路径，设为None不保存
)

# 4. 获取最重要的前K个特征（用于后续分析）
top_k = 5
if 'permutation_mean' in results:
    top_indices = np.argsort(results['permutation_mean'])[::-1][:top_k]
    print(f"\n最重要的{top_k}个特征索引: {top_indices}")
    print(f"对应的特征名称: {[feature_names[i] for i in top_indices]}")

# 5. 可选：基于重要性进行特征选择（移除低重要性特征）
threshold = 1.0  # 重要性阈值 (%)
if 'permutation_mean' in results:
    important_mask = results['permutation_mean'] > threshold
    selected_features = np.where(important_mask)[0]
    print(f"\n重要性 > {threshold}% 的特征索引: {selected_features}")
    print(f"建议保留 {len(selected_features)}/{M} 个特征")
# Out:
# 特征重要性图已保存至: feature_importance.png
# ==================================================
# 特征重要性评估结果
# ==================================================
#
# 【排列重要性 - Permutation Importance】
# 原理：打乱该特征后模型性能下降越多，特征越重要
#   1. Input_26       :  29.34% ± 120.72%
#   2. Input_27       :  19.03% ± 125.21%
#   3. Input_22       :  16.06% ± 60.32%
#   4. Input_25       :  13.98% ± 38.99%
#   5. Input_12       :   3.14% ±  8.38%
#   6. Input_28       :   3.12% ±  4.11%
#   7. Input_10       :   1.54% ±  3.51%
#   8. Input_1        :   1.51% ±  2.23%
#   9. Input_4        :   1.33% ±  1.86%
#   10. Input_7        :   1.29% ±  3.32%
#   11. Input_24       :   0.85% ±  1.31%
#   12. Input_15       :   0.81% ±  1.30%
#   13. Input_14       :   0.79% ±  3.12%
#   14. Input_13       :   0.73% ±  1.29%
#   15. Input_21       :   0.70% ±  2.34%
#   16. Input_8        :   0.68% ±  3.78%
#   17. Input_9        :   0.66% ±  2.67%
#   18. Input_11       :   0.65% ±  3.44%
#   19. Input_5        :   0.64% ±  2.06%
#   20. Input_20       :   0.60% ±  1.61%
#   21. Input_30       :   0.52% ±  2.02%
#   22. Input_17       :   0.47% ±  0.71%
#   23. Input_18       :   0.47% ±  1.40%
#   24. Input_16       :   0.27% ±  0.60%
#   25. Input_3        :   0.17% ±  1.31%
#   26. Input_2        :   0.15% ±  0.98%
#   27. Input_23       :   0.15% ±  1.36%
#   28. Input_19       :   0.14% ±  0.77%
#   29. Input_6        :   0.13% ±  0.87%
#   30. Input_29       :   0.07% ±  0.96%
#   31. Input_31       :   0.02% ±  0.47%
#
# 【梯度重要性 - Gradient Importance】
# 原理：输入梯度越大，输出对该特征越敏感
#   1. Input_26       :  10.78%
#   2. Input_25       :   9.74%
#   3. Input_22       :   7.36%
#   4. Input_27       :   5.57%
#   5. Input_8        :   4.63%
#   6. Input_11       :   4.46%
#   7. Input_28       :   4.31%
#   8. Input_5        :   4.01%
#   9. Input_14       :   3.97%
#   10. Input_7        :   3.94%
#   11. Input_4        :   3.67%
#   12. Input_13       :   3.63%
#   13. Input_12       :   3.36%
#   14. Input_30       :   3.27%
#   15. Input_18       :   3.13%
#   16. Input_21       :   2.83%
#   17. Input_10       :   2.81%
#   18. Input_17       :   1.93%
#   19. Input_20       :   1.72%
#   20. Input_9        :   1.70%
#   21. Input_24       :   1.65%
#   22. Input_23       :   1.62%
#   23. Input_19       :   1.59%
#   24. Input_1        :   1.57%
#   25. Input_3        :   1.54%
#   26. Input_15       :   1.43%
#   27. Input_2        :   0.99%
#   28. Input_16       :   0.91%
#   29. Input_29       :   0.73%
#   30. Input_31       :   0.60%
#   31. Input_6        :   0.57%
# ==================================================
#
# 最重要的5个特征索引: [25 26 21 24 11]
# 对应的特征名称: ['Input_26', 'Input_27', 'Input_22', 'Input_25', 'Input_12']
#
# 重要性 > 1.0% 的特征索引: [ 0  3  6  9 11 21 24 25 26 27]
# 建议保留 10/31 个特征
